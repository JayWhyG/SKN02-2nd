# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from dateutil.relativedelta import relativedelta
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import LabelEncoder
import warnings
warnings.filterwarnings(action='ignore')

# %%
data = pd.read_csv('./Customer_Subscription_And_Transaction_Details.csv') # 데이터 로드
data = data.dropna() # 결측값 처리
data
# Out:
#        cust_id transaction_type transaction_date subscription_type  \
# 0            1          initial       2020-09-01             BASIC
# 1            2          initial       2022-03-01             BASIC
# 2            3          initial       2020-10-01               MAX
# 3            3        REDUCTION       2022-02-01             BASIC
# 4            4          initial       2022-05-01               PRO
# ...        ...              ...              ...               ...
# 18101    10364          UPGRADE       2022-09-01               MAX
# 18102    10365          initial       2021-05-01               PRO
# 18103    10365        REDUCTION       2021-07-01             BASIC
# 18104    10366          initial       2021-01-01             BASIC
# 18105    10366            CHURN       2022-02-01             BASIC
#
#        subscription_price customer_gender age_group customer_country  \
# 0                      33            Male     35-44          Denmark
# 1                      53          Female     18-24          Denmark
# 2                      99          Female     25-34           Norway
# 3                      53          Female     25-34           Norway
# 4                      85            Male     18-24           Sweden
# ...                   ...             ...       ...              ...
# 18101                 119          Female     45-54           Norway
# 18102                  75            Male     55-65           Norway
# 18103                  43            Male     55-65           Norway
# 18104                  43            Male     18-24          Denmark
# 18105                  53            Male     18-24          Denmark
#
#       referral_type
# 0        Google Ads
# 1          facebook
# 2          facebook
# 3          facebook
# 4           Display
# ...             ...
# 18101      facebook
# 18102    Google Ads
# 18103    Google Ads
# 18104      facebook
# 18105      facebook
#
# [18106 rows x 9 columns]

# %%
data = pd.get_dummies(data,columns=['subscription_type', 'customer_country', 'transaction_type', 'customer_gender', 'referral_type', 'age_group']) # 원핫인코딩
data['transaction_date'] = pd.to_datetime(data['transaction_date']) #날짜 타임형식 변환

# %%
tmp_count = data[data['transaction_type_CHURN']]['cust_id'].value_counts() #CHURN 중복 찾기
tmp_count = tmp_count[tmp_count.values > 1] #CHURN 카운트 1이면 중복 아님

# %%
tmp_count #CHURN이 2와 3인 고객들
# Out:
# cust_id
# 7483    3
# 4479    3
# 9127    3
# 3946    3
# 6913    3
#        ..
# 2859    2
# 4873    2
# 5067    2
# 9839    2
# 7348    2
# Name: count, Length: 135, dtype: int64

# %%
(tmp_count[(tmp_count.values==3)].index) #CHURN이 3인 tmp_count의 인덱스가 cust_id
# Out:
# Index([7483, 4479, 9127, 3946, 6913, 9765, 8093, 3865], dtype='int64', name='cust_id')

# %%
data[data['cust_id'].isin(tmp_count[(tmp_count.values==3)].index)][data['transaction_type_CHURN']==True] #이 리스트에서 각 cust_id들의 마지막 행만 살리고 1,2번째는 원래 리스트에서 빠져야 하는 중복 CHURN 데이터
# Out:
#        cust_id transaction_date  subscription_price  subscription_type_BASIC  \
# 6738      3865       2021-12-01                  43                     True
# 6739      3865       2022-03-01                 119                    False
# 6740      3865       2022-04-01                 119                    False
# 6885      3946       2021-06-01                  43                     True
# 6886      3946       2021-10-01                  75                    False
# 6887      3946       2021-11-01                  43                     True
# 7835      4479       2021-09-01                  75                    False
# 7836      4479       2021-11-01                  43                     True
# 7837      4479       2022-03-01                  53                     True
# 12080     6913       2021-07-01                  75                    False
# 12081     6913       2022-02-01                 119                    False
# 12082     6913       2022-07-01                 119                    False
# 13094     7483       2022-03-01                  53                     True
# 13095     7483       2022-08-01                  85                    False
# 13096     7483       2022-11-01                  85                    False
# 14139     8093       2021-07-01                  75                    False
# 14140     8093       2021-08-01                 109                    False
# 14141     8093       2021-11-01                  75                    False
# 15959     9127       2021-02-01                  75                    False
# 15960     9127       2021-10-01                 109                    False
# 15961     9127       2022-02-01                 119                    False
# 17072     9765       2021-05-01                  75                    False
# 17074     9765       2022-09-01                 119                    False
# 17075     9765       2022-11-01                 119                    False
#
#        subscription_type_MAX  subscription_type_PRO  customer_country_Denmark  \
# 6738                   False                  False                     False
# 6739                    True                  False                     False
# 6740                    True                  False                     False
# 6885                   False                  False                     False
# 6886                   False                   True                     False
# 6887                   False                  False                     False
# 7835                   False                   True                     False
# 7836                   False                  False                     False
# 7837                   False                  False                     False
# 12080                  False                   True                     False
# 12081                   True                  False                     False
# 12082                   True                  False                     False
# 13094                  False                  False                      True
# 13095                  False                   True                      True
# 13096                  False                   True                      True
# 14139                  False                   True                     False
# 14140                   True                  False                     False
# 14141                  False                   True                     False
# 15959                  False                   True                     False
# 15960                   True                  False                     False
# 15961                   True                  False                     False
# 17072                  False                   True                      True
# 17074                   True                  False                      True
# 17075                   True                  False                      True
#
#        customer_country_Finland  customer_country_Norway  \
# 6738                       True                    False
# 6739                       True                    False
# 6740                       True                    False
# 6885                      False                    False
# 6886                      False                    False
# 6887                      False                    False
# 7835                       True                    False
# 7836                       True                    False
# 7837                       True                    False
# 12080                      True                    False
# 12081                      True                    False
# 12082                      True                    False
# 13094                     False                    False
# 13095                     False                    False
# 13096                     False                    False
# 14139                      True                    False
# 14140                      True                    False
# 14141                      True                    False
# 15959                      True                    False
# 15960                      True                    False
# 15961                      True                    False
# 17072                     False                    False
# 17074                     False                    False
# 17075                     False                    False
#
#        customer_country_Sweden  ...  referral_type_Organic Search  \
# 6738                     False  ...                         False
# 6739                     False  ...                         False
# 6740                     False  ...                         False
# 6885                      True  ...                         False
# 6886                      True  ...                         False
# 6887                      True  ...                         False
# 7835                     False  ...                         False
# 7836                     False  ...                         False
# 7837                     False  ...                         False
# 12080                    False  ...                          True
# 12081                    False  ...                          True
# 12082                    False  ...                          True
# 13094                    False  ...                         False
# 13095                    False  ...                         False
# 13096                    False  ...                         False
# 14139                    False  ...                          True
# 14140                    False  ...                          True
# 14141                    False  ...                          True
# 15959                    False  ...                         False
# 15960                    False  ...                         False
# 15961                    False  ...                         False
# 17072                    False  ...                         False
# 17074                    False  ...                         False
# 17075                    False  ...                         False
#
#        referral_type_Paid Search  referral_type_TV  referral_type_Unknown  \
# 6738                       False             False                  False
# 6739                       False             False                  False
# 6740                       False             False                  False
# 6885                       False             False                  False
# 6886                       False             False                  False
# 6887                       False             False                  False
# 7835                       False             False                  False
# 7836                       False             False                  False
# 7837                       False             False                  False
# 12080                      False             False                  False
# 12081                      False             False                  False
# 12082                      False             False                  False
# 13094                      False              True                  False
# 13095                      False              True                  False
# 13096                      False              True                  False
# 14139                      False             False                  False
# 14140                      False             False                  False
# 14141                      False             False                  False
# 15959                      False             False                  False
# 15960                      False             False                  False
# 15961                      False             False                  False
# 17072                      False             False                   True
# 17074                      False             False                   True
# 17075                      False             False                   True
#
#        referral_type_facebook  age_group_18-24  age_group_25-34  \
# 6738                    False            False            False
# 6739                    False            False            False
# 6740                    False            False            False
# 6885                     True            False             True
# 6886                     True            False             True
# 6887                     True            False             True
# 7835                    False             True            False
# 7836                    False             True            False
# 7837                    False             True            False
# 12080                   False            False            False
# 12081                   False            False            False
# 12082                   False            False            False
# 13094                   False            False             True
# 13095                   False            False             True
# 13096                   False            False             True
# 14139                   False             True            False
# 14140                   False             True            False
# 14141                   False             True            False
# 15959                   False             True            False
# 15960                   False             True            False
# 15961                   False             True            False
# 17072                   False             True            False
# 17074                   False             True            False
# 17075                   False             True            False
#
#        age_group_35-44  age_group_45-54  age_group_55-65
# 6738              True            False            False
# 6739              True            False            False
# 6740              True            False            False
# 6885             False            False            False
# 6886             False            False            False
# 6887             False            False            False
# 7835             False            False            False
# 7836             False            False            False
# 7837             False            False            False
# 12080             True            False            False
# 12081             True            False            False
# 12082             True            False            False
# 13094            False            False            False
# 13095            False            False            False
# 13096            False            False            False
# 14139            False            False            False
# 14140            False            False            False
# 14141            False            False            False
# 15959            False            False            False
# 15960            False            False            False
# 15961            False            False            False
# 17072            False            False            False
# 17074            False            False            False
# 17075            False            False            False
#
# [24 rows x 30 columns]

# %%
tmp_del = data[data['cust_id'].isin(tmp_count[(tmp_count.values==3)].index)][data['transaction_type_CHURN']==True] #중복된 것들 중 CHURN이 3개인 cust_id 만 모아서 그 중 CHURN을 제외한 type은 제외한 데이터프레임
result = tmp_del.groupby('cust_id',as_index=False,group_keys=False).apply(lambda x: x.iloc[:2]) #tmp_del에 있는 CHURN 중에서 최종 탈퇴 CHURN 행만 빼고 나머지를 데이터프레임으로 만드는 코드(인덱스 유지를 위해 False로)

# %%
result
# Out:
#        cust_id transaction_date  subscription_price  subscription_type_BASIC  \
# 6738      3865       2021-12-01                  43                     True
# 6739      3865       2022-03-01                 119                    False
# 6885      3946       2021-06-01                  43                     True
# 6886      3946       2021-10-01                  75                    False
# 7835      4479       2021-09-01                  75                    False
# 7836      4479       2021-11-01                  43                     True
# 12080     6913       2021-07-01                  75                    False
# 12081     6913       2022-02-01                 119                    False
# 13094     7483       2022-03-01                  53                     True
# 13095     7483       2022-08-01                  85                    False
# 14139     8093       2021-07-01                  75                    False
# 14140     8093       2021-08-01                 109                    False
# 15959     9127       2021-02-01                  75                    False
# 15960     9127       2021-10-01                 109                    False
# 17072     9765       2021-05-01                  75                    False
# 17074     9765       2022-09-01                 119                    False
#
#        subscription_type_MAX  subscription_type_PRO  customer_country_Denmark  \
# 6738                   False                  False                     False
# 6739                    True                  False                     False
# 6885                   False                  False                     False
# 6886                   False                   True                     False
# 7835                   False                   True                     False
# 7836                   False                  False                     False
# 12080                  False                   True                     False
# 12081                   True                  False                     False
# 13094                  False                  False                      True
# 13095                  False                   True                      True
# 14139                  False                   True                     False
# 14140                   True                  False                     False
# 15959                  False                   True                     False
# 15960                   True                  False                     False
# 17072                  False                   True                      True
# 17074                   True                  False                      True
#
#        customer_country_Finland  customer_country_Norway  \
# 6738                       True                    False
# 6739                       True                    False
# 6885                      False                    False
# 6886                      False                    False
# 7835                       True                    False
# 7836                       True                    False
# 12080                      True                    False
# 12081                      True                    False
# 13094                     False                    False
# 13095                     False                    False
# 14139                      True                    False
# 14140                      True                    False
# 15959                      True                    False
# 15960                      True                    False
# 17072                     False                    False
# 17074                     False                    False
#
#        customer_country_Sweden  ...  referral_type_Organic Search  \
# 6738                     False  ...                         False
# 6739                     False  ...                         False
# 6885                      True  ...                         False
# 6886                      True  ...                         False
# 7835                     False  ...                         False
# 7836                     False  ...                         False
# 12080                    False  ...                          True
# 12081                    False  ...                          True
# 13094                    False  ...                         False
# 13095                    False  ...                         False
# 14139                    False  ...                          True
# 14140                    False  ...                          True
# 15959                    False  ...                         False
# 15960                    False  ...                         False
# 17072                    False  ...                         False
# 17074                    False  ...                         False
#
#        referral_type_Paid Search  referral_type_TV  referral_type_Unknown  \
# 6738                       False             False                  False
# 6739                       False             False                  False
# 6885                       False             False                  False
# 6886                       False             False                  False
# 7835                       False             False                  False
# 7836                       False             False                  False
# 12080                      False             False                  False
# 12081                      False             False                  False
# 13094                      False              True                  False
# 13095                      False              True                  False
# 14139                      False             False                  False
# 14140                      False             False                  False
# 15959                      False             False                  False
# 15960                      False             False                  False
# 17072                      False             False                   True
# 17074                      False             False                   True
#
#        referral_type_facebook  age_group_18-24  age_group_25-34  \
# 6738                    False            False            False
# 6739                    False            False            False
# 6885                     True            False             True
# 6886                     True            False             True
# 7835                    False             True            False
# 7836                    False             True            False
# 12080                   False            False            False
# 12081                   False            False            False
# 13094                   False            False             True
# 13095                   False            False             True
# 14139                   False             True            False
# 14140                   False             True            False
# 15959                   False             True            False
# 15960                   False             True            False
# 17072                   False             True            False
# 17074                   False             True            False
#
#        age_group_35-44  age_group_45-54  age_group_55-65
# 6738              True            False            False
# 6739              True            False            False
# 6885             False            False            False
# 6886             False            False            False
# 7835             False            False            False
# 7836             False            False            False
# 12080             True            False            False
# 12081             True            False            False
# 13094            False            False            False
# 13095            False            False            False
# 14139            False            False            False
# 14140            False            False            False
# 15959            False            False            False
# 15960            False            False            False
# 17072            False            False            False
# 17074            False            False            False
#
# [16 rows x 30 columns]

# %%
data.drop(result.index,inplace=True) #원본 data에서 result의 인덱스가 그대로 인덱스를 가지고 있으므로 인덱스를 기준으로 사이에 껴있는 CHURN 행 삭제

# %%
#중복이 2인 애들 다시 반복

# %%
tmp_del = data[data['cust_id'].isin(tmp_count[(tmp_count.values==2)].index)][data['transaction_type_CHURN']==True] #중복된 것들 중 CHURN이 2개인 cust_id 만 모아서 그 중 CHURN을 제외한 type은 제외한 데이터프레임
result = tmp_del.groupby('cust_id',as_index=False,group_keys=False).apply(lambda x: x.iloc[:1]) #tmp_del에 있는 CHURN 중에서 최종 탈퇴 CHURN 행만 빼고 나머지를 데이터프레임으로 만드는 코드(인덱스 유지를 위해 False로)

# %%
data.drop(result.index,inplace=True) #원본 data에서 result의 인덱스가 그대로 인덱스를 가지고 있으므로 인덱스를 기준으로 사이에 껴있는 CHURN 행 삭제

# %%
#data.to_csv('drop_dataset.csv')

# %%
data
# Out:
#        cust_id transaction_date  subscription_price  subscription_type_BASIC  \
# 0            1       2020-09-01                  33                     True
# 1            2       2022-03-01                  53                     True
# 2            3       2020-10-01                  99                    False
# 3            3       2022-02-01                  53                     True
# 4            4       2022-05-01                  85                    False
# ...        ...              ...                 ...                      ...
# 18101    10364       2022-09-01                 119                    False
# 18102    10365       2021-05-01                  75                    False
# 18103    10365       2021-07-01                  43                     True
# 18104    10366       2021-01-01                  43                     True
# 18105    10366       2022-02-01                  53                     True
#
#        subscription_type_MAX  subscription_type_PRO  customer_country_Denmark  \
# 0                      False                  False                      True
# 1                      False                  False                      True
# 2                       True                  False                     False
# 3                      False                  False                     False
# 4                      False                   True                     False
# ...                      ...                    ...                       ...
# 18101                   True                  False                     False
# 18102                  False                   True                     False
# 18103                  False                  False                     False
# 18104                  False                  False                      True
# 18105                  False                  False                      True
#
#        customer_country_Finland  customer_country_Norway  \
# 0                         False                    False
# 1                         False                    False
# 2                         False                     True
# 3                         False                     True
# 4                         False                    False
# ...                         ...                      ...
# 18101                     False                     True
# 18102                     False                     True
# 18103                     False                     True
# 18104                     False                    False
# 18105                     False                    False
#
#        customer_country_Sweden  ...  referral_type_Organic Search  \
# 0                        False  ...                         False
# 1                        False  ...                         False
# 2                        False  ...                         False
# 3                        False  ...                         False
# 4                         True  ...                         False
# ...                        ...  ...                           ...
# 18101                    False  ...                         False
# 18102                    False  ...                         False
# 18103                    False  ...                         False
# 18104                    False  ...                         False
# 18105                    False  ...                         False
#
#        referral_type_Paid Search  referral_type_TV  referral_type_Unknown  \
# 0                          False             False                  False
# 1                          False             False                  False
# 2                          False             False                  False
# 3                          False             False                  False
# 4                          False             False                  False
# ...                          ...               ...                    ...
# 18101                      False             False                  False
# 18102                      False             False                  False
# 18103                      False             False                  False
# 18104                      False             False                  False
# 18105                      False             False                  False
#
#        referral_type_facebook  age_group_18-24  age_group_25-34  \
# 0                       False            False            False
# 1                        True             True            False
# 2                        True            False             True
# 3                        True            False             True
# 4                       False             True            False
# ...                       ...              ...              ...
# 18101                    True            False            False
# 18102                   False            False            False
# 18103                   False            False            False
# 18104                    True             True            False
# 18105                    True             True            False
#
#        age_group_35-44  age_group_45-54  age_group_55-65
# 0                 True            False            False
# 1                False            False            False
# 2                False            False            False
# 3                False            False            False
# 4                False            False            False
# ...                ...              ...              ...
# 18101            False             True            False
# 18102            False            False             True
# 18103            False            False             True
# 18104            False            False            False
# 18105            False            False            False
#
# [17963 rows x 30 columns]

# %%
17963+2*8+1*127
# Out:
# 18106

# %%
#data = pd.read_csv('./drop_dataset.csv')

# %%
#탈퇴한 회원인지 확인하는 열을 추가하고 구독기간을 계산하는 과정 (2023년1월1월기준)

# %%
data_initial = data[data['transaction_type_initial']==True] #initial인 행만 추출
tmp = data[data['transaction_type_CHURN']==True]['cust_id'] #탈퇴한 회원의 id 추출

# %%
Out_date = data[data['transaction_type_CHURN']==True].reset_index() #탈퇴한 사람들 모아놓은 데이터프레임
in_date = data_initial[data_initial['cust_id'].isin(tmp)].reset_index() #initial이 모여있는 데이터에서 탈퇴한 회원 데이터인 tmp에 id가 존재하는 것들만 뽑아낸 데이터프레임

# %%
in_date
# Out:
#       index  cust_id transaction_date  subscription_price  \
# 0         8        8       2021-01-01                  43
# 1        10        9       2020-08-01                  33
# 2        23       17       2021-12-01                  43
# 3        31       22       2022-06-01                  53
# 4        39       26       2021-02-01                  43
# ...     ...      ...              ...                 ...
# 2047  18045    10328       2021-10-01                  43
# 2048  18062    10340       2020-05-01                  65
# 2049  18084    10355       2020-05-01                  33
# 2050  18097    10363       2020-10-01                  65
# 2051  18104    10366       2021-01-01                  43
#
#       subscription_type_BASIC  subscription_type_MAX  subscription_type_PRO  \
# 0                        True                  False                  False
# 1                        True                  False                  False
# 2                        True                  False                  False
# 3                        True                  False                  False
# 4                        True                  False                  False
# ...                       ...                    ...                    ...
# 2047                     True                  False                  False
# 2048                    False                  False                   True
# 2049                     True                  False                  False
# 2050                    False                  False                   True
# 2051                     True                  False                  False
#
#       customer_country_Denmark  customer_country_Finland  \
# 0                        False                     False
# 1                        False                     False
# 2                         True                     False
# 3                        False                      True
# 4                        False                     False
# ...                        ...                       ...
# 2047                      True                     False
# 2048                     False                     False
# 2049                     False                      True
# 2050                     False                      True
# 2051                      True                     False
#
#       customer_country_Norway  ...  referral_type_Organic Search  \
# 0                       False  ...                         False
# 1                       False  ...                         False
# 2                       False  ...                         False
# 3                       False  ...                         False
# 4                       False  ...                         False
# ...                       ...  ...                           ...
# 2047                    False  ...                         False
# 2048                    False  ...                         False
# 2049                    False  ...                         False
# 2050                    False  ...                         False
# 2051                    False  ...                         False
#
#       referral_type_Paid Search  referral_type_TV  referral_type_Unknown  \
# 0                         False             False                  False
# 1                         False             False                  False
# 2                         False             False                   True
# 3                         False             False                   True
# 4                          True             False                  False
# ...                         ...               ...                    ...
# 2047                      False             False                  False
# 2048                      False              True                  False
# 2049                      False              True                  False
# 2050                      False             False                  False
# 2051                      False             False                  False
#
#       referral_type_facebook  age_group_18-24  age_group_25-34  \
# 0                       True            False            False
# 1                       True            False             True
# 2                      False            False            False
# 3                      False            False             True
# 4                      False            False            False
# ...                      ...              ...              ...
# 2047                    True            False            False
# 2048                   False            False            False
# 2049                   False            False            False
# 2050                   False             True            False
# 2051                    True             True            False
#
#       age_group_35-44  age_group_45-54  age_group_55-65
# 0               False             True            False
# 1               False            False            False
# 2               False             True            False
# 3               False            False            False
# 4                True            False            False
# ...               ...              ...              ...
# 2047            False             True            False
# 2048             True            False            False
# 2049             True            False            False
# 2050            False            False            False
# 2051            False            False            False
#
# [2052 rows x 31 columns]

# %%
Out_date
# Out:
#       index  cust_id transaction_date  subscription_price  \
# 0         9        8       2021-04-01                  43
# 1        11        9       2021-03-01                  43
# 2        24       17       2022-08-01                  53
# 3        32       22       2022-11-01                  53
# 4        41       26       2022-10-01                  85
# ...     ...      ...              ...                 ...
# 2047  18046    10328       2022-04-01                  53
# 2048  18063    10340       2021-06-01                  75
# 2049  18085    10355       2020-11-01                  33
# 2050  18099    10363       2022-02-01                  53
# 2051  18105    10366       2022-02-01                  53
#
#       subscription_type_BASIC  subscription_type_MAX  subscription_type_PRO  \
# 0                        True                  False                  False
# 1                        True                  False                  False
# 2                        True                  False                  False
# 3                        True                  False                  False
# 4                       False                  False                   True
# ...                       ...                    ...                    ...
# 2047                     True                  False                  False
# 2048                    False                  False                   True
# 2049                     True                  False                  False
# 2050                     True                  False                  False
# 2051                     True                  False                  False
#
#       customer_country_Denmark  customer_country_Finland  \
# 0                        False                     False
# 1                        False                     False
# 2                         True                     False
# 3                        False                      True
# 4                        False                     False
# ...                        ...                       ...
# 2047                      True                     False
# 2048                     False                     False
# 2049                     False                      True
# 2050                     False                      True
# 2051                      True                     False
#
#       customer_country_Norway  ...  referral_type_Organic Search  \
# 0                       False  ...                         False
# 1                       False  ...                         False
# 2                       False  ...                         False
# 3                       False  ...                         False
# 4                       False  ...                         False
# ...                       ...  ...                           ...
# 2047                    False  ...                         False
# 2048                    False  ...                         False
# 2049                    False  ...                         False
# 2050                    False  ...                         False
# 2051                    False  ...                         False
#
#       referral_type_Paid Search  referral_type_TV  referral_type_Unknown  \
# 0                         False             False                  False
# 1                         False             False                  False
# 2                         False             False                   True
# 3                         False             False                   True
# 4                          True             False                  False
# ...                         ...               ...                    ...
# 2047                      False             False                  False
# 2048                      False              True                  False
# 2049                      False              True                  False
# 2050                      False             False                  False
# 2051                      False             False                  False
#
#       referral_type_facebook  age_group_18-24  age_group_25-34  \
# 0                       True            False            False
# 1                       True            False             True
# 2                      False            False            False
# 3                      False            False             True
# 4                      False            False            False
# ...                      ...              ...              ...
# 2047                    True            False            False
# 2048                   False            False            False
# 2049                   False            False            False
# 2050                   False             True            False
# 2051                    True             True            False
#
#       age_group_35-44  age_group_45-54  age_group_55-65
# 0               False             True            False
# 1               False            False            False
# 2               False             True            False
# 3               False            False            False
# 4                True            False            False
# ...               ...              ...              ...
# 2047            False             True            False
# 2048             True            False            False
# 2049             True            False            False
# 2050            False            False            False
# 2051            False            False            False
#
# [2052 rows x 31 columns]

# %%
Out_date['transaction_date'] = pd.to_datetime(Out_date['transaction_date'])
in_date['transaction_date'] = pd.to_datetime(in_date['transaction_date'])

# %%
tmp_date = data[data['transaction_type_CHURN']==True].reset_index() #임시 데이터프레임 생성

# %%
tmp_date['period'] = Out_date['transaction_date'] - in_date['transaction_date'] #날짜 계산

# %%
tmp_date = tmp_date[['cust_id', 'period']] #두 개의 행만 가진 데이터프레임 생성

# %%
data2 = pd.merge(data, tmp_date, on='cust_id', how='left')

# %%
data2.head(20)
# Out:
#     cust_id transaction_date  subscription_price  subscription_type_BASIC  \
# 0         1       2020-09-01                  33                     True
# 1         2       2022-03-01                  53                     True
# 2         3       2020-10-01                  99                    False
# 3         3       2022-02-01                  53                     True
# 4         4       2022-05-01                  85                    False
# 5         5       2022-08-01                  53                     True
# 6         6       2022-06-01                 119                    False
# 7         7       2022-02-01                 119                    False
# 8         8       2021-01-01                  43                     True
# 9         8       2021-04-01                  43                     True
# 10        9       2020-08-01                  33                     True
# 11        9       2021-03-01                  43                     True
# 12       10       2022-09-01                 119                    False
# 13       11       2020-05-01                  33                     True
# 14       11       2022-01-01                 119                    False
# 15       12       2020-09-01                  33                     True
# 16       12       2022-09-01                  85                    False
# 17       13       2022-06-01                  53                     True
# 18       14       2020-03-01                  33                     True
# 19       14       2020-07-01                  65                    False
#
#     subscription_type_MAX  subscription_type_PRO  customer_country_Denmark  \
# 0                   False                  False                      True
# 1                   False                  False                      True
# 2                    True                  False                     False
# 3                   False                  False                     False
# 4                   False                   True                     False
# 5                   False                  False                     False
# 6                    True                  False                     False
# 7                    True                  False                     False
# 8                   False                  False                     False
# 9                   False                  False                     False
# 10                  False                  False                     False
# 11                  False                  False                     False
# 12                   True                  False                     False
# 13                  False                  False                     False
# 14                   True                  False                     False
# 15                  False                  False                     False
# 16                  False                   True                     False
# 17                  False                  False                     False
# 18                  False                  False                     False
# 19                  False                   True                     False
#
#     customer_country_Finland  customer_country_Norway  \
# 0                      False                    False
# 1                      False                    False
# 2                      False                     True
# 3                      False                     True
# 4                      False                    False
# 5                      False                    False
# 6                      False                    False
# 7                      False                    False
# 8                      False                    False
# 9                      False                    False
# 10                     False                    False
# 11                     False                    False
# 12                      True                    False
# 13                     False                     True
# 14                     False                     True
# 15                      True                    False
# 16                      True                    False
# 17                     False                     True
# 18                     False                     True
# 19                     False                     True
#
#     customer_country_Sweden  ...  referral_type_Paid Search  referral_type_TV  \
# 0                     False  ...                      False             False
# 1                     False  ...                      False             False
# 2                     False  ...                      False             False
# 3                     False  ...                      False             False
# 4                      True  ...                      False             False
# 5                      True  ...                      False             False
# 6                      True  ...                      False             False
# 7                      True  ...                      False             False
# 8                      True  ...                      False             False
# 9                      True  ...                      False             False
# 10                     True  ...                      False             False
# 11                     True  ...                      False             False
# 12                    False  ...                      False             False
# 13                    False  ...                      False             False
# 14                    False  ...                      False             False
# 15                    False  ...                      False             False
# 16                    False  ...                      False             False
# 17                    False  ...                      False             False
# 18                    False  ...                      False             False
# 19                    False  ...                      False             False
#
#     referral_type_Unknown  referral_type_facebook  age_group_18-24  \
# 0                   False                   False            False
# 1                   False                    True             True
# 2                   False                    True            False
# 3                   False                    True            False
# 4                   False                   False             True
# 5                   False                   False            False
# 6                   False                    True            False
# 7                   False                    True            False
# 8                   False                    True            False
# 9                   False                    True            False
# 10                  False                    True            False
# 11                  False                    True            False
# 12                  False                    True            False
# 13                  False                   False            False
# 14                  False                   False            False
# 15                  False                    True            False
# 16                  False                    True            False
# 17                  False                   False            False
# 18                  False                   False            False
# 19                  False                   False            False
#
#     age_group_25-34  age_group_35-44  age_group_45-54  age_group_55-65  \
# 0             False             True            False            False
# 1             False            False            False            False
# 2              True            False            False            False
# 3              True            False            False            False
# 4             False            False            False            False
# 5             False             True            False            False
# 6             False            False            False             True
# 7              True            False            False            False
# 8             False            False             True            False
# 9             False            False             True            False
# 10             True            False            False            False
# 11             True            False            False            False
# 12             True            False            False            False
# 13            False            False             True            False
# 14            False            False             True            False
# 15             True            False            False            False
# 16             True            False            False            False
# 17            False            False            False             True
# 18            False             True            False            False
# 19            False             True            False            False
#
#      period
# 0       NaT
# 1       NaT
# 2       NaT
# 3       NaT
# 4       NaT
# 5       NaT
# 6       NaT
# 7       NaT
# 8   90 days
# 9   90 days
# 10 212 days
# 11 212 days
# 12      NaT
# 13      NaT
# 14      NaT
# 15      NaT
# 16      NaT
# 17      NaT
# 18      NaT
# 19      NaT
#
# [20 rows x 31 columns]

# %%
data2['transaction_date'] = pd.to_datetime(data2['transaction_date'])

# %%
Churn = data2[data2['transaction_type_CHURN']==True]['cust_id'].unique() #탈퇴가 기록된 사람들의 id를 뽑아낸 리스트

# %%
data2['churn_result'] = data2['cust_id'].apply(lambda x: True if x in Churn else False) #탈퇴했으면 True 유지고객이면 False로 해서 data2에 새로운 'churn_result' 컬럼 추가

# %%
c_date = '2023-01-01'#유지중인 고객의 유지 기간을 알기 위해 데이터에 있는 마지막 날짜인 2022년 12월 이후인 2023년 1월 1일로 기준 날짜 설정
c_date = pd.to_datetime(c_date)

# %%
data2.loc[data2['period'].isnull(), 'period'] = c_date - data2['transaction_date'] #c_date에서 가입한 날짜를 뺀 것을 data2의 각 줄 period에 저장

# %%
# for i in range(len(data2)):
#     if (data2['period'].isnull())[i]==True:
#         data2['period'][i] = c_date - data2['transaction_date'][i]

# %%
data2['period'] = data2['period'].astype(str)

# %%
data2['period'] = data2['period'].str.replace(' days', '')

# %%
data2['period'] = data2['period'].astype(int)

# %%
data2['period'] = (data2['period']/30).astype(int)

# %%
data2 #최종 데이터 확인
# Out:
#        cust_id transaction_date  subscription_price  subscription_type_BASIC  \
# 0            1       2020-09-01                  33                     True
# 1            2       2022-03-01                  53                     True
# 2            3       2020-10-01                  99                    False
# 3            3       2022-02-01                  53                     True
# 4            4       2022-05-01                  85                    False
# ...        ...              ...                 ...                      ...
# 17958    10364       2022-09-01                 119                    False
# 17959    10365       2021-05-01                  75                    False
# 17960    10365       2021-07-01                  43                     True
# 17961    10366       2021-01-01                  43                     True
# 17962    10366       2022-02-01                  53                     True
#
#        subscription_type_MAX  subscription_type_PRO  customer_country_Denmark  \
# 0                      False                  False                      True
# 1                      False                  False                      True
# 2                       True                  False                     False
# 3                      False                  False                     False
# 4                      False                   True                     False
# ...                      ...                    ...                       ...
# 17958                   True                  False                     False
# 17959                  False                   True                     False
# 17960                  False                  False                     False
# 17961                  False                  False                      True
# 17962                  False                  False                      True
#
#        customer_country_Finland  customer_country_Norway  \
# 0                         False                    False
# 1                         False                    False
# 2                         False                     True
# 3                         False                     True
# 4                         False                    False
# ...                         ...                      ...
# 17958                     False                     True
# 17959                     False                     True
# 17960                     False                     True
# 17961                     False                    False
# 17962                     False                    False
#
#        customer_country_Sweden  ...  referral_type_TV  referral_type_Unknown  \
# 0                        False  ...             False                  False
# 1                        False  ...             False                  False
# 2                        False  ...             False                  False
# 3                        False  ...             False                  False
# 4                         True  ...             False                  False
# ...                        ...  ...               ...                    ...
# 17958                    False  ...             False                  False
# 17959                    False  ...             False                  False
# 17960                    False  ...             False                  False
# 17961                    False  ...             False                  False
# 17962                    False  ...             False                  False
#
#        referral_type_facebook  age_group_18-24  age_group_25-34  \
# 0                       False            False            False
# 1                        True             True            False
# 2                        True            False             True
# 3                        True            False             True
# 4                       False             True            False
# ...                       ...              ...              ...
# 17958                    True            False            False
# 17959                   False            False            False
# 17960                   False            False            False
# 17961                    True             True            False
# 17962                    True             True            False
#
#        age_group_35-44  age_group_45-54  age_group_55-65  period  churn_result
# 0                 True            False            False      28         False
# 1                False            False            False      10         False
# 2                False            False            False      27         False
# 3                False            False            False      11         False
# 4                False            False            False       8         False
# ...                ...              ...              ...     ...           ...
# 17958            False             True            False       4         False
# 17959            False            False             True      20         False
# 17960            False            False             True      18         False
# 17961            False            False            False      13          True
# 17962            False            False            False      13          True
#
# [17963 rows x 32 columns]

# %%
data2.corr()['transaction_type_CHURN'].sort_values()
# Out:
# transaction_type_initial       -0.419493
# transaction_type_UPGRADE       -0.160995
# transaction_type_REDUCTION     -0.145704
# period                         -0.122670
# customer_country_Norway        -0.105094
# customer_country_Sweden        -0.090559
# subscription_type_MAX          -0.056335
# subscription_price             -0.035873
# referral_type_Organic Search   -0.018890
# age_group_45-54                -0.016133
# customer_gender_Other          -0.012110
# customer_gender_Female         -0.010894
# cust_id                        -0.006106
# referral_type_Display          -0.005193
# referral_type_Google Ads        0.000581
# age_group_55-65                 0.000839
# referral_type_Unknown           0.003015
# age_group_35-44                 0.003781
# age_group_25-34                 0.004138
# subscription_type_PRO           0.004173
# referral_type_facebook          0.004796
# referral_type_Paid Search       0.005030
# referral_type_Bing              0.005981
# age_group_18-24                 0.006600
# referral_type_TV                0.007850
# customer_gender_Male            0.017681
# subscription_type_BASIC         0.047033
# transaction_date                0.077435
# customer_country_Denmark        0.087312
# customer_country_Finland        0.123481
# churn_result                    0.569472
# transaction_type_CHURN          1.000000
# Name: transaction_type_CHURN, dtype: float64

# %%
#data2.to_csv('period_add_dataset.csv',index=False)
